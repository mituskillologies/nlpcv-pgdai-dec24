# %%
pip install pronouncing
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pronouncing

def get_phonetic_transcription(word):
    # Get a list of possible pronunciations for the word
    pronunciations = pronouncing.phones_for_word(word)
    
    if pronunciations:
        return pronunciations[0]  # Return the first transcription
    else:
        return "No phonetic transcription found"

# Example usage
word = "bat"
transcription = get_phonetic_transcription(word)
print(f"Phonetic transcription of '{word}': {transcription}")
# Out:
# Phonetic transcription of 'bat': B AE1 T

# %%
pronouncing.rhymes(word)
# Out:
# ['arnatt',
#  'at',
#  'at-bat',
#  'balyeat',
#  'batt',
#  'batte',
#  'begat',
#  'bhatt',
#  'biernat',
#  'blatt',
#  'brat',
#  'bratt',
#  'cat',
#  'catt',
#  'chat',
#  'combat',
#  'dat',
#  'delatte',
#  'deslatte',
#  'elat',
#  'fat',
#  'flat',
#  'flatt',
#  'gat',
#  'gatt',
#  'glatt',
#  'gnat',
#  'gujarat',
#  'hat',
#  'hatt',
#  'hnat',
#  'inmarsat',
#  'jagt',
#  'kat',
#  'katt',
#  'klatt',
#  'krat',
#  'kratt',
#  'labatt',
#  'landsat',
#  'lat',
#  'mat',
#  'matt',
#  'matte',
#  'mcnatt',
#  'nat',
#  'non-fat',
#  'nonfat',
#  'pat',
#  'patt',
#  'platt',
#  'platte',
#  'pratt',
#  'pratte',
#  'prevatt',
#  'prevatte',
#  'rat',
#  'rat-a-tat',
#  'ratte',
#  'sadat',
#  'sarratt',
#  'sat',
#  'scat',
#  'schadt',
#  'shatt',
#  'slaght',
#  'slat',
#  'spat',
#  'splat',
#  'spratt',
#  'stat',
#  'tat',
#  'that',
#  'tit-for-tat',
#  'tvsat',
#  'vat']

# %%
len(pronouncing.pronunciations)
# Out:
# 135167

# %%
pronouncing.pronunciations
# Out:
# [("'bout", 'B AW1 T'),
#  ("'cause", 'K AH0 Z'),
#  ("'course", 'K AO1 R S'),
#  ("'cuse", 'K Y UW1 Z'),
#  ("'em", 'AH0 M'),
#  ("'frisco", 'F R IH1 S K OW0'),
#  ("'gain", 'G EH1 N'),
#  ("'kay", 'K EY1'),
#  ("'m", 'AH0 M'),
#  ("'n", 'AH0 N'),
#  ("'round", 'R AW1 N D'),
#  ("'s", 'EH1 S'),
#  ("'til", 'T IH1 L'),
#  ("'tis", 'T IH1 Z'),
#  ("'twas", 'T W AH1 Z'),
#  ('a', 'AH0'),
#  ('a', 'EY1'),
#  ("a's", 'EY1 Z'),
#  ('a.', 'EY1'),
#  ("a.'s", 'EY1 Z'),
#  ('a.d.', 'EY2 D IY1'),
#  ('a.m.', 'EY2 EH1 M'),
#  ('a.s', 'EY1 Z'),
#  ('aaa', 'T R IH2 P AH0 L EY1'),
#  ('aaberg', 'AA1 B ER0 G'),
#  ('aachen', 'AA1 K AH0 N'),
#  ('aachener', 'AA1 K AH0 N ER0'),
#  ('aaker', 'AA1 K ER0'),
#  ('aalborg', 'AO1 L B AO0 R G # place, danish'),
#  ('aalborg', 'AA1 L B AO0 R G'),
#  ('aalburg', 'AE1 L B ER0 G # place, dutch'),
#  ('aalen', 'AE1 L AH0 N # place, german'),
#  ('aalen', 'AA1 L AH0 N'),
#  ('aaliyah', 'AA2 L IY1 AA2'),
#  ('aalseth', 'AA1 L S EH0 TH'),
# ...

# %%
pronouncing.rhyming_part('creation')
# Out:
# 'creation'

# %%
dict(pronouncing.pronunciations)['round']
# Out:
# 'R AW1 N D'

# %%
dict(pronouncing.pronunciations)['the']
# Out:
# 'DH IY0'
